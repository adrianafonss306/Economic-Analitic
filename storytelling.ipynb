# %% [markdown]
# Título:
# "LOS DÍAS GRISES: CRÓNICA NUMÉRICA DE LA JUBILACIÓN EN CUBA"
#
# Introducción:
# Hay una Cuba de la que no se suele hablar con frecuencia: la de los abuelos que cuentan monedas al final del mes. En un país donde las canas estan en constante aumento, hemos seguido los números detrás de la supervivencia diaria. Esta es la historia que cuentan las estadísticas cuando nadie las escucha.
#
# Los números son fríos pero elocuentes, asi que veamos que esta causando este envejecimiento poblacional:

# %%
from modules import *
from charts import *

print(Chart_Elder_Population())
print(Chart_Live_Births())
# Out:
# None
# None

# %% [markdown]
#  En 2019 nacían 109,716 cubanos; en 2024 solo 71,358. Mientras, la plataforma de la tercera edad se llena. Por cada niño que nace hoy, hay dos personas mayores de 60 años. De esa manera queda demostrado el motivo por el cual la poblacion cubana se ve tan envejecida en los ultimos años

# %%
from modules import *
from charts import *

print(Chart_Aging_Rate())
# Out:
# None

# %% [markdown]
# Por primera vez en nuestra historia, los abuelos superan en número a los nietos. Este cambio demográfico debería venir acompañado de políticas robustas de protección social, pero los datos cuentan una historia diferente.
#
# Recopilamos precios de 30 mipymes diferentes en La Habana, escogiendo productos con precios no topados por la ley para apreciar mejor los cambios.

# %%
from modules import *
from charts import *

print(Chart_Analiced_Products())
# Out:
# None

# %% [markdown]
# Se distribuyeron los productos anteriormente mostrados en 2 canastas:
#
# CANASTA BASICA:
#
# | Producto         | Tipo       | Medida | Cantidad |
# |------------------|------------|--------|----------|
# | Arroz            | –          | kg     | 7        |
# | Azúcar           | –          | kg     | 3        |
# | Sal              | –          | kg     | 1.0      |
# | Café             | –          | kg     | 0.25     |
# | Pastas           | –          | kg     | 0.5      |
# | Puré de tomate   | –          | kg     | 0.5      |
# | Jabón            | Tocador    | kg     | 0.09     |
# | Jabón            | Lavar      | kg     | 0.2      |
# | Papel sanitario  | –          | rollos | 4        |
# | Detergente       | –          | kg     | 1        |
# | Detergente       | –          | L      | 1        |
# | Desodorante      | –          | L      | 0.09     |
# | Pasta dental     | –          | kg     | 0.15     |
#
#
# CANASTA ADICIONAL:
#
# | Producto          | Medida    | Cantidad |
# |-------------------|-----------|----------|
# | Avena             | kg        | 0.5      |
# | Shampoo           | L         | 0.7      |
# | Acondicionador    | L         | 0.7      |
# | Crema corporal    | L         | 0.5      |
# | Pañales de adulto | unidades  | 20       |
# | Toallitas húmedas | unidades  | 80       |
#
#
# Pues a pesar de no ser imprescindibles estos productos para vivir, le suman comodidad a nuestros ancianos y algunos como es el caso del cafe, se han vuelto un imprescindible en la vida del adulto mayor cubano
#
#
#
# Comparando tambien los precios de los productos con las posibilidades salariales de los pensionados en Cuba, nos muestra que a pesar de haber sido esta tarifa incrementada ultimamente, aun no les propicia estabilidad economica

# %%
from modules import *
from charts import *

print(Chart_Average_VS_Salary())
# Out:
# None

# %% [markdown]
# Ademas, como dato curioso, se hizo notable que la disponibilidad de un producto de higiene y salud como es el caso de los pañales de adultos, se encuentra solo en lugares aislados, pues no abunda en el mercado popular.

# %%
from modules import *
from charts import *

print(Chart_Diaper_Availability())
# Out:
# None
