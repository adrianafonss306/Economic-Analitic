# %% [markdown]
# ### "LOS DÍAS GRISES: CRÓNICA NUMÉRICA DE LA JUBILACIÓN EN CUBA"
#
#
# Hay una Cuba de la que no se suele hablar con frecuencia: la de los abuelos que cuentan monedas al final del mes. En un país donde las canas estan en constante aumento, hemos seguido los números detrás de la supervivencia diaria. Esta es la historia que cuentan las estadísticas cuando nadie las escucha.

# %% [markdown]
# En el corazón de La Habana, como en tantos otros rincones de la isla, el tiempo parece haberse detenido. Pero los números no mienten: la población mayor de 60 años no para de crecer. Año tras año, más cubanos cruzan ese umbral invisible que los lleva a depender de una pensión que, como el mar, sube y baja, pero nunca alcanza la orilla del bienestar.
#
# La gráfica de la población anciana muestra una línea ascendente imparable, como las arrugas en un rostro que ha visto demasiados amaneceres. Cada punto en esa curva representa historias silenciadas, sueños pospuestos y una pregunta que resuena en cada esquina: ¿cómo sobrevivir cuando la vida se alarga pero los recursos se acortan?

# %%
from modules import *
from charts import *

# %%
Chart_Elder_Population()

# %% [markdown]
# Mientras los abuelos aumentan, los cunas se vacían. En 2019 nacían 109.716 cubanos; en 2024 solo 71.358. La curva de nacimientos desciende como un suspiro apagado, como si la isla hubiera decidido dejar de soñar en nuevos comienzos.
#
# Por cada niño que nace hoy, hay dos personas mayores de 60 años. Este desbalance no es solo demográfico; es un reflejo de un presente incierto, donde la juventud mira al futuro con escepticismo y prefiere no traer al mundo a quienes heredarán sus mismas incertidumbres.

# %%
Chart_Birth_Rate()

# %% [markdown]
# Así queda demostrado el motivo por el cual la población cubana se ve tan envejecida en los últimos años. No es solo un fenómeno estadístico; es un relato colectivo escrito en números y silencios.

# %%
Chart_Aging_Rate()

# %% [markdown]
# Por primera vez en nuestra historia, los abuelos superan en número a los nietos. Este cambio demográfico debería venir acompañado de políticas robustas de protección social, pero los datos cuentan una historia diferente. La jubilación, que debería garantizar tranquilidad en la vejez, se enfrenta a un mercado minorista donde las MiPymes ofrecen lo que el negocio necesita, pero a precios que muchas veces superan lo que un jubilado puede pagar, dejando a los adultos mayores en una encrucijada diaria entre necesidad y posibilidad.
#
# Este escenario de vulnerabilidad económica no es solo una percepción: lo hemos contrastado con datos concretos. Para comprender cómo los precios del mercado minorista afectan directamente la capacidad de consumo de los jubilados, recopilamos información de 30 mipymes en La Habana, enfocándonos en productos sin precios topados por la ley. Esta clasificación nos permite observar con mayor claridad las necesidades reales del adulto mayor cubano frente a un mercado que no siempre se ajusta a sus ingresos fijos.

# %% [markdown]
# CANASTA BASICA:
#
# | Producto         | Tipo       | Medida | Cantidad |
# |------------------|------------|--------|----------|
# | Arroz            | –          | kg     | 7        |
# | Azúcar           | –          | kg     | 3        |
# | Sal              | –          | kg     | 1.0      |
# | Café             | –          | kg     | 0.25     |
# | Pastas           | –          | kg     | 0.5      |
# | Puré de tomate   | –          | kg     | 0.5      |
# | Jabón            | Tocador    | kg     | 0.09     |
# | Jabón            | Lavar      | kg     | 0.2      |
# | Papel sanitario  | –          | rollos | 4        |
# | Detergente       | –          | kg     | 1        |
# | Detergente       | –          | L      | 1        |
# | Desodorante      | –          | L      | 0.09     |
# | Pasta dental     | –          | kg     | 0.15     |
#
#
# CANASTA ADICIONAL:
#
# | Producto          | Medida    | Cantidad |
# |-------------------|-----------|----------|
# | Avena             | kg        | 0.5      |
# | Shampoo           | L         | 0.7      |
# | Acondicionador    | L         | 0.7      |
# | Crema corporal    | L         | 0.5      |
# | Pañales de adulto | unidades  | 1       |
# | Toallitas húmedas | unidades  | 1      |
#
#
# A pesar de no ser imprescindibles para la supervivencia, muchos de estos productos suman comodidad a la vida de nuestros ancianos y, en casos como el café, se han convertido en verdaderos imprescindibles en la rutina del adulto mayor cubano. Al mismo tiempo, forman parte de lo que habitualmente se encuentra en el mercado minorista y marcan el día a día del consumo. La gráfica de precios promedio refleja precisamente esa realidad: muestra el costo de los artículos más comunes en las mipymes, evidenciando cómo lo cotidiano se convierte en un factor clave para comprender las necesidades de este grupo poblacional.

# %%
Chart_Analiced_Products()

# %% [markdown]
# Comparando los precios de los productos con las posibilidades salariales de los pensionados en Cuba, se observa que, aun cuando las pensiones han sido incrementadas en los últimos años, este ajuste no ha logrado traducirse en estabilidad económica. El aumento nominal se diluye frente al comportamiento del mercado minorista, donde los precios de los artículos más comunes en las mipymes siguen siendo elevados. La consecuencia es que cada mes los adultos mayores deben decidir cuáles de estos productos pueden permitirse y cuáles deberán dejar fuera de su consumo, convirtiendo la planificación de la compra en un ejercicio extenuante.

# %%
Chart_Average_VS_Salary()

# %% [markdown]
# Teniendo en cuenta estos elevados precios, es notable como el poder adquisitivo de los jubilados ha cambiado, pues su pension se diluye frente al comportamiento del mercado minorista. La gráfica del poder adquisitivo muestra con claridad esta brecha entre ingresos y costos, evidenciando que el incremento de las pensiones aún no garantiza una mejora sustancial en la calidad de vida de los adultos mayores.

# %%
Chart_Max_Salary_VS_Basket()

# %% [markdown]
# Un dato curioso que emergió del análisis es la escasa disponibilidad de pañales de adulto en las mipymes habaneras. A pesar de ser un producto clave para la comodidad y el cuidado de los mayores, los datos revelan que menos del 40% de los establecimientos los ofrecen de manera regular. Esta baja presencia en el mercado contrasta con la importancia que tienen en la vida cotidiana de los jubilados, mostrando que no solo el precio limita el acceso, sino también la propia posibilidad de encontrarlos.

# %%
Chart_Diaper_Availability()

# %% [markdown]
# ### Conclusiones
#
#
# Esta investigacion muestra una tendencia sostenida hacia el envejecimiento poblacional, acompañada por una disminución pronunciada en la tasa de natalidad. Esta dinámica responde a un patrón de transición demográfica caracterizado por el incremento en la esperanza de vida y la reducción de nuevos nacimientos, lo que conlleva una proporción cada vez mayor de adultos mayores en la estructura poblacional.
#
# Más allá de la tendencia numérica, los datos evidencian una realidad socioeconómica que afecta directamente a este grupo etario: incluso ante aumentos en los montos de pensión, los jubilados enfrentan una insuficiencia económica persistente. Los ingresos fijos resultan insuficientes para cubrir la canasta básica y bienes adicionales, reflejando un déficit estructural en su poder adquisitivo que limita su acceso a productos esenciales y los expone a una creciente vulnerabilidad social.
#
# Esta situación plantea desafíos multifacéticos en términos de sostenibilidad del sistema de pensiones, dinámica del mercado laboral y diseño de políticas de atención social, además de influir en la futura composición de la fuerza productiva y en la demanda de servicios especializados para la tercera edad.
#
# Si bien este fenómeno no es exclusivo de Cuba —formando parte de procesos demográficos globales—, sus particularidades nacionales exigen respuestas adaptadas que consideren tanto el contexto económico como las necesidades específicas de una población envejecida, con el fin de asegurar una calidad de vida digna y un sistema de protección social sostenible a largo plazo.
